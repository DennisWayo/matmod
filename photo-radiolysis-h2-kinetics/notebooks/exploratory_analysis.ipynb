# %% [markdown]
# # Exploratory Analysis
#
# This notebook is an optional scratchpad for inspecting outputs generated by scripts in `data/outputs/`.

# %%
from pathlib import Path
import pandas as pd

root = Path('..').resolve()
base_csv = root / 'data' / 'outputs' / 'base_case' / 'timeseries_coupled.csv'
df = pd.read_csv(base_csv)
df.head()
